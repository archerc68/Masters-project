# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

# %%
xvals = np.linspace(0, 1, 100)

# %% [markdown]
# Y values

# %%
def y(x):
    return x**2 + 1

yvals = y(xvals)

# %% [markdown]
# Plotting

# %%
plt.figure()
plt.plot(xvals, yvals)
plt.show()
